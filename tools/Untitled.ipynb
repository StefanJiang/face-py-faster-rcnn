# %%
python ./vis_face_detection.py
# Out:
#   File "<ipython-input-5-031034166206>", line 1
#     python ./vis_face_detection.py
#             ^
# SyntaxError: invalid syntax

# %%
pwd
# Out:
# u'/home/zjian30/test/face-py-faster-rcnn/tools'

# %%
run ./vis_face_detection.py aaa

# %%
run ./vis_face_detection.py img_1005-Copy1.jpg --cpu
# Out:
# Loaded network /home/zjian30/test/face-py-faster-rcnn/output/faster_rcnn_end2end/train/vgg16_faster_rcnn_iter_80000.caffemodel
# 106.941376 33.540257 188.528107 148.695419 0.999899
#
# 112.193024 36.162663 190.304779 149.574249 0.999899
#
# 104.403542 38.226372 185.303589 148.489532 0.999899
#
# 111.902870 35.786976 188.669556 148.894821 0.999899
#
# 111.187057 36.528160 193.374557 150.850494 0.999899
#
# 107.702026 36.584053 192.266510 147.900055 0.999899
#
# 107.223785 32.903984 190.143768 149.004639 0.999899
#
# 105.031296 33.645710 189.833145 150.357712 0.999899
#
# 110.767792 39.363049 188.545410 150.860611 0.999899
#
# 107.181938 36.066086 187.878021 145.086868 0.999899
#
# 107.022552 38.677483 188.023346 148.453827 0.999899
#
# 110.870300 34.116383 186.347809 152.021927 0.999896
#
# 105.842995 32.659790 189.334412 149.543976 0.999896
#
# 108.917175 37.524647 180.208282 148.593536 0.999892
#
# 107.081497 39.602146 180.318649 148.184280 0.999865
#
# ...

# %%
pwd
# Out:
# u'/home/zjian30/test/face-py-faster-rcnn/tools'

# %%
run ./vis_face_detection.py img_1005-Copy1.jpg --gpu=0

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
im = 128 * np.ones((300, 500, 3), dtype=np.uint8)

# %%
plt.plot(im)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-6d1a16ec35d5> in <module>()
# ----> 1 plt.plot(im)
#
# /usr/lib64/python2.7/site-packages/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    3316                       mplDeprecation)
#    3317     try:
# -> 3318         ret = ax.plot(*args, **kwargs)
#    3319     finally:
#    3320         ax._hold = washold
#
# /usr/lib64/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1890                     warnings.warn(msg % (label_namer, func.__name__),
#    1891                                   RuntimeWarning, stacklevel=2)
# -> 1892             return func(ax, *args, **kwargs)
#    1893         pre_doc = inner.__doc__
#    1894         if pre_doc is None:
#
# /usr/lib64/python2.7/site-packages/matplotlib/axes/_axes.pyc in plot(self, *args, **kwargs)
# ...

# %%
plt.imshow(im)

# %%
# %matplotlib inline

# %%
import matplotlib as mpl
mpl.use('Agg')
import matplotlib.pyplot as plt
# %matplotlib inline
